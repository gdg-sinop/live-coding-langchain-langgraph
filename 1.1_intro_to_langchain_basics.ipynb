# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %% [markdown]
# ## Iniciando e invocando um modelo

# %% [markdown]
# Inicializa o chat com os provedores de AI, define configurações da integração

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(
    model="gpt-5-nano"
)

# %% [markdown]
# O invoke é é utilizado para interagir com o modelo, permite passar suas definições de payload de entrada.

# %%
response = model.invoke("Oi, qual é a capital do Nortão do Mato Grosso?")

response
# Out:
# AIMessage(content='Não existe uma capital oficial do “Nortão” — é uma região do estado de Mato Grosso, não uma entidade com governo próprio. A capital de Mato Grosso é Cuiabá. \n\nNo uso popular, algumas pessoas chamam Sinop de “capital do Nortão” por ser o maior polo da região, mas isso é apenas uma expressão informal, não oficial. Quer saber mais sobre as cidades principais do Nortão? Posso indicar.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 995, 'prompt_tokens': 19, 'total_tokens': 1014, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 896, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DA2G37bbYbKOvmKw1fifTXhffPDOA', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c68c5-fb48-7ef3-918c-76a202d6bf87-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 19, 'output_tokens': 995, 'total_tokens': 1014, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 896}})

# %%
print(response.content)
# Out:
# Não existe uma capital oficial do “Nortão” — é uma região do estado de Mato Grosso, não uma entidade com governo próprio. A capital de Mato Grosso é Cuiabá.
#
# No uso popular, algumas pessoas chamam Sinop de “capital do Nortão” por ser o maior polo da região, mas isso é apenas uma expressão informal, não oficial. Quer saber mais sobre as cidades principais do Nortão? Posso indicar.

# %% [markdown]
# Resultado da sua chaama como dados de tokens, modelo, etc...

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-DA2G37bbYbKOvmKw1fifTXhffPDOA',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 995,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 896,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 19,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 1014}}

# %% [markdown]
# ## Customização do modelo

# %% [markdown]
# - temperature: calibra o modelo para ser mais criativo/determínistico - temperaturas altas torna as respostas do modelo mais criativo, ao passo que temperaturas baixas mais determinístico
# - max_tokens: limita o total de numero de gerados na respota, controlando o tamanho do output do modelo
# - timeout: o maximo de tempo que devemos aguardar a resposta do modelo até que a request seja cancelada
# - max_retries: maximo de retentativa se a request falhar

# %%
model = init_chat_model(
    model="gpt-5-nano",
    max_tokens=5000,
    temperature=0.7,
    timeout=60,
    max_retries=3,
)

response = model.invoke("Qual a capital do Brasil?")
print(response.content)
# Out:
# A capital do Brasil é Brasília.

# %% [markdown]
# ## Model Providers

# %% [markdown]
# Vefirique as integrações disponiveis e capacidades de cada provider para o langchain
#
# https://docs.langchain.com/oss/python/integrations/chat

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3-flash-preview")

response = model.invoke("Qual é a capital do Brasil?")
print(response.content)
# Out:
# [{'type': 'text', 'text': 'A capital do Brasil é **Brasília**.', 'extras': {'signature': '...'}}]

# %% [markdown]
# ## Inicando e invocando um agente

# %% [markdown]
# O create_agent do langchain segue o padrão ReAct (pensar->agir->observar->responder)
#
# A diferença para a chamada do model direto é que o agent executa um orquestrador por baixo dos panos, capaz de gerenciar estado das msgs, chamadas de ferramentas e criterios de parada.

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %% [markdown]
# HumanMessage representa as interações (user input) do usuario

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="Qual é a capital do Brasil?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Qual é a capital do Brasil?', additional_kwargs={}, response_metadata={}, id='b622fcb7-c11c-44e1-9521-b133f8b268b8'),
#               AIMessage(content=[{'type': 'text', 'text': 'A capital do Brasil é **Brasília**.', 'extras': {'signature': ''}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019c68c6-2a18-7202-afac-d99ea63567cb-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 62, 'total_tokens': 70, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 53}})]}

# %%
print(response["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': 'A capital do Brasil é **Brasília**.', 'extras': {'signature': ''}}]

# %% [markdown]
# A lista de mensagens passada ao agent representa a memória de curto prazo, nesse caso estamos fazendo o controle manual do histórico.
# Isso singifica que o agente é capaz de entender o contexto das mensagens trocadas entre user e ai, e responder adequadamente com base no contexto fornecido.

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {
        "messages": [
            HumanMessage(content="Qual é a capital do Brasil?"),
            AIMessage(content="Brasília."),
            HumanMessage(content="Me fale mais sobre Brasília")
        ]
    }
)

# %%
print(response["messages"][-1])
# Out:
# content=[{'type': 'text', 'text': 'Brasília é uma cidade única, conhecida mundialmente por seu planejamento urbano e arquitetura modernista. Aqui estão os pontos principais para entender a capital do Brasil:\n\n### 1. História e Fundação\n*   **Inauguração:** Foi inaugurada em **21 de abril de 1960** pelo então presidente **Juscelino Kubitschek (JK)**.\n*   **Objetivo:** A ideia era transferir a capital do litoral (Rio de Janeiro) para o interior do país para integrar as diversas regiões do Brasil e garantir a segurança nacional, afastando o centro das decisões de possíveis ataques marítimos.\n*   **Construção recorde:** A cidade foi construída em menos de quatro anos (cerca de 41 meses), um feito impressionante para a época.\n\n### 2. Planejamento Urbano (Plano Piloto)\n*   **Lúcio Costa:** Foi o urbanista responsável pelo projeto da cidade, chamado de **Plano Piloto**.\n*   **Formato:** O desenho da cidade é frequentemente comparado ao formato de um **avião** ou de uma borboleta.\n*   **Divisão:** A cidade é dividida em setores específicos (Setor Hoteleiro, Setor Bancário, Setor de Embaixadas) e em "Asas" (Asa Sul e Asa Norte), onde ficam as áreas residenciais.\n*   **Endereços:** O sistema de endereçamento é baseado em coordenadas e siglas, como SQN (Superquadra Norte) ou CLS (Comércio Local Sul), o que pode confundir quem visita a cidade pela primeira vez.\n\n### 3. Arquitetura de Oscar Niemeyer\nBrasília é um museu a céu aberto da arquitetura modernista. Oscar Niemeyer projetou os principais prédios públicos, caracterizados pelas curvas e pelo uso do concreto armado. Os marcos mais famosos são:\n*   **Congresso Nacional:** Com suas duas cúpulas (uma para cima e outra para baixo) e as torres gêmeas.\n*   **Catedral Metropolitana:** Com suas colunas curvas que representam mãos voltadas para o céu.\n*   **Palácio do Planalto:** Sede da Presidência da República.\n*   **Supremo Tribunal Federal (STF).**\n*   **Palácio do Itamaraty:** Sede do Ministério das Relações Exteriores, considerado uma obra-prima de design e paisagismo (de Roberto Burle Marx).\n\n### 4. Patrimônio da Humanidade\nEm 1987, Brasília foi declarada **Patrimônio Cultural da Humanidade pela UNESCO**. É a maior área urbana do mundo com esse título, devido ao seu conjunto urbanístico e arquitetônico inovador.\n\n### 5. Geografia e Clima\n*   **Localização:** Fica no Distrito Federal, na região Centro-Oeste, no Planalto Central.\n*   **Lago Paranoá:** É um grande lago artificial criado para aumentar a umidade da região e oferecer lazer.\n*   **Clima:** O clima é o Tropical de Altitude. A cidade tem duas estações bem definidas: um verão chuvoso e um inverno extremamente seco (entre julho e setembro), quando a umidade pode baixar a níveis de deserto.\n*   **O "Céu de Brasília":** Como a cidade é plana e não tem prédios muito altos fora dos eixos, o horizonte é vasto. Os moradores costumam dizer que "o céu é o mar de Brasília".\n\n### 6. Curiosidades\n*   **Ausência de esquinas:** No Plano Piloto, quase não existem esquinas ou semáforos em cruzamentos; em vez disso, utilizam-se os "trevos" ou as famosas **"tesourinhas"** para o fluxo de carros.\n*   **Cidade multicultural:** Por ser a capital federal, abriga pessoas de todos os estados do Brasil e de quase todos os países do mundo (através das embaixadas).\n\nBrasília não é apenas o centro político do país, mas também um símbolo de modernidade e do sonho de desenvolvimento do Brasil no século XX.', 'extras': {'signature': '...'}}] additional_kwargs={} response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3-flash-preview', 'safety_ratings': [], 'model_provider': 'google_genai'} id='lc_run--019c68c6-2f27-7a53-a346-c7c51c9c1cc5-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 18, 'output_tokens': 1400, 'total_tokens': 1418, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 521}}

# %% [markdown]
# ## Prompt do Sistema

# %% [markdown]
# Um sistem prompt é a camada de instrução de maior contexto em uma chamada ao modelo.
# Ele basicamene define o comportamento de base do assistente: papel, tom, limites, formatos de resposta, políticas, objetivos, etc...

# %%
products = [
    {
        "id": 1,
        "name": "Casa terrea, 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²",
        "price": 700000,
        "location": "Rua das Flores, 123",
    },
    {
        "id": 2,
        "name": "Apartamento 3 dormitórios, 2 banheiros, 2 vagas de garagem, 120m²",
        "price": 800000,
        "location": "Rua das Avencas, 123",
    },
]

products_formatted = "\n".join([f"ID: {p['id']}\nNome: {p['name']}\nPreço: {p['price']}\nLocalização: {p['location']}" for p in products])

system_prompt = f"""
Você é um assistente de vendas focado no mercado imobiliário.

Seus produtos são imóveis de alto padrão, com preços a partir de R$ 700.000,00

Aqui estão os imóveis disponíveis para venda:
{products_formatted}
"""

seller_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt
)

# %%
user_question = "Qual é o imóvel mais barato da região?"

response = seller_agent.invoke(
    {"messages": [HumanMessage(content=user_question)]}
)

print(response['messages'][1].content)
# Out:
# O imóvel mais barato disponível é a Casa térrea (ID 1) por R$ 700.000,00. Detalhes: 3 dormitórios, 2 banheiros, 2 vagas, 200 m². Localização: Rua das Flores, 123.
#
# Deseja agendar uma visita ou precisa de mais informações sobre este imóvel?

# %% [markdown]
# ## Saídas estruturadas

# %% [markdown]
# Uma resposta estruturada é o meio que temos para fazer com que o modelo retorne dados num formato previsível ao invés de um texto livre.

# %%
from langchain.agents import create_agent
from langchain.messages import HumanMessage
from pydantic import BaseModel

class Product(BaseModel):
    id: int
    name: str
    price: float
    location: str

seller_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt,
    response_format=Product
)

response = seller_agent.invoke(
    {"messages": [HumanMessage(content=user_question)]}
)

product = response["structured_response"]

print(product.id)
print(product.name)
print(product.price)
print(product.location)
# Out:
# 1
# Casa terrea, 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²
# 700000.0
# Rua das Flores, 123

# %% [markdown]
# ## Definições de ferramentas

# %% [markdown]
# ferramentas (tools) são funções que você expõe para o agente agir no mundo externo (fazer cálculo, consultar API, buscar dados, etc.),

# %%
from langchain.tools import tool

@tool
def calculate_installments(price: float, installments: int):
    """
    Calcula o valor das parcelas de um produto
    """

    if installments <= 0:
        return "O número de parcelas deve ser maior que 0"
    
    return price / installments

# %% [markdown]
# podemos invocar as ferramentas diretamente

# %%
calculate_installments.invoke({"price": 1000, "installments": 5})
# Out:
# 200.0

# %% [markdown]
# ## Adicionando as ferramentas ao agent

# %%
seller_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt,
    tools=[calculate_installments]
)

user_question = "Qual o valor parcelado em 10x do imóvel mais barato?"

response = seller_agent.invoke(
    {"messages": [HumanMessage(content=user_question)]}
)

print(response["messages"][-1].content)
# Out:
# Imóvel mais barato:
# - Casa térrea, 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²
# - Localização: Rua das Flores, 123
# - Preço: R$ 700.000,00
#
# Parcela em 10x: R$ 70.000,00 por mês (total de R$ 700.000,00).
#
# Deseja que eu simule com entrada ou com outras condições de pagamento?

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content='Qual o valor parcelado em 10x do imóvel mais barato?', additional_kwargs={}, response_metadata={}, id='38ef5319-388b-42aa-9839-be92b64eb184'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 414, 'prompt_tokens': 289, 'total_tokens': 703, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DA2GjxABoPIiEi6jNeCZ5j3VhTDce', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c68c6-a043-71e1-8f43-cd99792c72ac-0', tool_calls=[{'name': 'calculate_installments', 'args': {'price': 700000, 'installments': 10}, 'id': 'call_ZgrTFiP865OxHvvoTYFCczb4', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 289, 'output_tokens': 414, 'total_tokens': 703, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}}),
#  ToolMessage(content='70000.0', name='calculate_installments', id='058e3809-3845-4ceb-af89-5a20b89b3707', tool_call_id='call_ZgrTFiP865OxHvvoTYFCczb4'),
#  AIMessage(content='Imóvel mais barato:\n- Casa térrea, 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²\n- Localização: Rua das Flores, 123\n- Preço: R$ 700.000,00\n\nParcela em 10x: R$ 70.000,00 por mês (total de R$ 700.000,00).\n\nDeseja que eu simule com entrada ou com outras condições de pagamento?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 811, 'prompt_tokens': 329, 'total_tokens': 1140, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 704, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DA2GnpiSIcffQe2MtyHDlHxK2f2AD', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c68c6-af8d-7e00-81c1-abfd6b6b8148-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 329, 'output_tokens': 811, 'total_tokens': 1140, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 704}})]

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'calculate_installments', 'args': {'price': 700000, 'installments': 10}, 'id': 'call_ZgrTFiP865OxHvvoTYFCczb4', 'type': 'tool_call'}]

# %% [markdown]
# ## Pesquisa na internet

# %%
from tavily import TavilyClient
from typing import Dict, Any

tavily_client = TavilyClient()

@tool
def search_internet(query: str)  -> Dict[str, Any]:
    """
    Pesquisa na internet
    """
    return tavily_client.search(query)

# %%
seller_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt,
    tools=[calculate_installments, search_internet]
)

user_question = "Procure por imóveis de alto padrão em Sinop, na região do bairro Aquarela das Artes"

response = seller_agent.invoke(
    {"messages": [HumanMessage(content=user_question)]}
)

print(response["messages"][-1].content)
# Out:
# Encontrei algumas opções de alto padrão no bairro Aquarela das Artes, em Sinop. Abaixo, um resumo com os pontos principais e preços quando disponíveis:
#
# - Casa de alto padrão no Aquarela das Artes
#   - Preço: R$ 1.600.000
#   - Características: 3 suítes (1 master com closet), sala com pé-direito alto, cozinha gourmet com ilha e churrasqueira, lavabo, lavanderia, garagem para 2 vagas, sacada com vista para a orla. Observação: anúncio afirma also piscina com cascata, aquecida e hidro.
#
# - Casa de frente para a orla - Aquarela das Artes
#   - Preço: não informado publicamente
#   - Características: 3 suítes, piscina, vista para a orla. Área total citada: cerca de 323m² de terreno, 260m² de área coberta incluindo piscina.
#
# - Imóvel com 2 quartos/1 suíte no Aquarela das Artes
#   - Preço: não informado
#   - Dimensões: terreno 170m², área construída 102m²
#
# - Residencial Aquarela das Artes (outros anúncios)
#   - Preço: não informado
#   - Características: 3 suítes (inclui master com closet), piscina entre outros detalhes citados nos anúncios.
#
# - Domus Brokers – Casa de Alto Padrão no Aquarela das Artes
#   - Preço: não informado
#   - Características: 3 suítes (uma master), cozinha gourmet, lavabo, área de festas/lavanderia, etc.
#
# Observação prática:
# - Vários anúncios não divulgam o preço de venda de forma pública. Posso entrar em contato com os anunciantes para confirmar valores, disponibilidade e agendar visitas.
#
# Para eu refinar ainda mais a busca, pode me dizer:
# 1) Qual é seu orçamento máximo?
# 2) Quantos dormitórios você prefere e necessidade de suíte? há interesse específico em piscina, churrasqueira, varanda, vagas de garagem, etc.?
# 3) Quer que eu procure apenas imóveis prontos para venda com visita disponível ou também opções em plantas/lançamento?
#
# Se quiser, eu já começo a contatar os anúncios para confirmar preços/horários de visita e monto uma shortlist personalizada.

# %%
print(response["messages"][1].tool_calls)
# Out:
# [{'name': 'search_internet', 'args': {'query': 'Sinop Aquarela das Artes imobiliário alto padrão'}, 'id': 'call_fNuyC55CN6YA2OTUEcPL8O6y', 'type': 'tool_call'}]

# %%
## Memória

# %% [markdown]
# Vamos adicionar memória multi-turn automatico para nosso agent.

# %%
from langgraph.checkpoint.memory import InMemorySaver  

seller_agent = create_agent(
    model="gpt-5-nano",
    system_prompt=system_prompt,
    tools=[calculate_installments, search_internet],
    checkpointer=InMemorySaver()
)

config = {"configurable": {"thread_id": "123"}}

user_question = "Oi, minhas preferências são: 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²"

response = seller_agent.invoke(
    {"messages": [HumanMessage(content=user_question)]},
    config=config
)

print(response["messages"][-1].content)
# Out:
# Ótimo! com base nas suas preferências, o imóvel que atende exatamente é:
#
# - ID 1: Casa térrea, 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²
#   - Preço: R$ 700.000
#   - Localização: Rua das Flores, 123
#
# Observação: o ID 2 também é 3 dormitórios, 2 banheiros e 2 vagas, mas tem 120m² (não atende aos 200m² desejados).
#
# Como gostaria de seguir?
# - Agendar uma visita ao ID 1
# - Pedir mais fotos/plantas do ID 1
# - Calcular parcelas de pagamento (diga em quantas parcelas quer; posso usar simulações como 12x, 24x, 60x, etc.)

# %% [markdown]
# **Lista de messages manual vs checkpointer**
#
# Na lista de mensagens (HumanMessage, AIMessage, HumanMessage), estamos fazendo memória manual: passa todo o contexto explicitamente a cada invoke. (Stateless por padrão.)
# Com checkpointer=InMemorySaver() + thread_id, ativamos memória automática por thread: o agente salva/recupera estado entre chamadas, sem precisar reenviar todo o histórico. (Stateful por sessão/conversa.)

# %%
pprint(response)
# Out:
# {'messages': [HumanMessage(content='Oi, minhas preferências são: 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²', additional_kwargs={}, response_metadata={}, id='325c8c2c-66d7-4038-aca3-68e9bcca3ae7'),
#               AIMessage(content='Ótimo! com base nas suas preferências, o imóvel que atende exatamente é:\n\n- ID 1: Casa térrea, 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²\n  - Preço: R$ 700.000\n  - Localização: Rua das Flores, 123\n\nObservação: o ID 2 também é 3 dormitórios, 2 banheiros e 2 vagas, mas tem 120m² (não atende aos 200m² desejados).\n\nComo gostaria de seguir?\n- Agendar uma visita ao ID 1\n- Pedir mais fotos/plantas do ID 1\n- Calcular parcelas de pagamento (diga em quantas parcelas quer; posso usar simulações como 12x, 24x, 60x, etc.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1590, 'prompt_tokens': 320, 'total_tokens': 1910, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DA2gdxlZ15nDEhZv9UP9Mqk2pXwhW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c68df-1e97-7f53-8dce-26ba59e6bdf0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 320, 'output_tokens': 1590, 'total_tokens': 1910, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1408}})]}

# %%
question = HumanMessage(content="Pesquise por casas que se encaixam nas minhas preferências com localização no bairro Aquarela das Artes")

response = seller_agent.invoke(
    {"messages": [question]},
    config,  
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Oi, minhas preferências são: 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²', additional_kwargs={}, response_metadata={}, id='325c8c2c-66d7-4038-aca3-68e9bcca3ae7'),
#               AIMessage(content='Ótimo! com base nas suas preferências, o imóvel que atende exatamente é:\n\n- ID 1: Casa térrea, 3 dormitórios, 2 banheiros, 2 vagas de garagem, 200m²\n  - Preço: R$ 700.000\n  - Localização: Rua das Flores, 123\n\nObservação: o ID 2 também é 3 dormitórios, 2 banheiros e 2 vagas, mas tem 120m² (não atende aos 200m² desejados).\n\nComo gostaria de seguir?\n- Agendar uma visita ao ID 1\n- Pedir mais fotos/plantas do ID 1\n- Calcular parcelas de pagamento (diga em quantas parcelas quer; posso usar simulações como 12x, 24x, 60x, etc.)', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1590, 'prompt_tokens': 320, 'total_tokens': 1910, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1408, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DA2gdxlZ15nDEhZv9UP9Mqk2pXwhW', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c68df-1e97-7f53-8dce-26ba59e6bdf0-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 320, 'output_tokens': 1590, 'total_tokens': 1910, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1408}}),
#               HumanMessage(content='Pesquise por casas que se encaixam nas minhas preferências com localização no bairro Aquarela das Artes', additional_kwargs={}, response_metadata={}, id='27878447-ce1d-4480-b2c0-0c30ea84a58c'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 684, 'prompt_tokens': 524, 'total_tokens': 1208, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DA2h7a46p55Twb3W8ZmMxT9qDkBIr', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019c68df-95f8-7971-a2e6-02b183fccd76-0', tool_calls=[{'name': 'search_internet', 'args': {'query': 'casas 3 dormitorios 2 banheiros 2 vagas 200m² Aquarela das Artes'}, 'id': 'call_1z10dLoxS4FrgnNu0DyU4RkX', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 524, 'output_tokens': 684, 'total_tokens': 1208, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}}),
#               ToolMessage(content='{"query": "casas 3 dormitorios 2 banheiros 2 vagas 200m² Aquarela das Artes", "follow_up_questions": null, "answer": null, "images": [], "results": [{"url": "https://www.vivareal.com.br/venda/mato-grosso/sinop/bairros/aquarela-das-artes/avenida-das-artes/", "title": "5 Imóveis à venda na Avenida das Artes - Aquarela das Artes, Sinop", "content": "Casa para comprar com 215 m², 3 banheiros, 2 vagas em Aquarela das Artes, Sinop · Tamanho do imóvel 215 m² · Quantidade de banheiros 3 · Quantidade de vagas de", "score": 0.9999826, "raw_content": null}, {"url": "https://www.instagram.com/p/DLP24D8MN-L/?hl=bn", "title": "Casa a venda no Bairro Aquarela das Artes 3 suites, 2 vagas de ...", "content": "OPORTUNIDADE! Casa com piscina pelo valor de R$ 490.000,00. Excelente oportunidade para quem busca conforto, espaço e lazer completo! Detalhes do imóvel:", "score": 0.9999465, "raw_content": null}, {"url": "https://www.zapimoveis.com.br/venda/casas/mt+sinop++aquarela-das-artes/3-quartos/", "title": "17 Casas com 3 quartos à venda em Aquarela das Artes, Sinop - MT", "content": "17 Casas com 3 quartos à venda em Aquarela das Artes, Sinop - MT · Casa para comprar com 188 m², 3 quartos, 3 banheiros, 2 vagas em Aquarela das Artes, Sinop.", "score": 0.9998134, "raw_content": null}, {"url": "https://bazaimob.com.br/imovel/casa-a-venda-no-aquarela-das-artes/4036", "title": "Casa A Venda No Aquarela Das Artes - Sinop/MT - Baza Imobiliária", "content": "... AQUARELA DAS ARTES. VALOR. VENDA. R$ 1.580.000,00. Valor M²: R$ 9.575,76. SIMULAR FINANCIAMENTO. INFORMAÇÕES. 1 Suíte(s). 3 Quarto(s). 2 Banheiro(s). 1 Sala(s).", "score": 0.99973255, "raw_content": null}, {"url": "https://portal.kenlo.com.br/imoveis/para-alugar+a-venda/casa/sinop/aquarela-das-artes", "title": "Casas para alugar e à venda Aquarela das Artes, Sinop - MT - Kenlo", "content": "Casa. Aquarela das Artes - Sinop - MT. 171.89 m²; 3 Quartos; 3 Suítes; 1 Banheiro; 2 Vagas. Venda. R$ 1.650.000 · Aquarela das Artes - Sinop - MT, Sinop - MT.", "score": 0.9997284, "raw_content": null}], "response_time": 0.73, "request_id": "55a80c85-a12e-4683-9a3b-119d4a73c41b"}', name='search_internet', id='35445bd7-e706-463b-804b-1b4293e9877a', tool_call_id='call_1z10dLoxS4FrgnNu0DyU4RkX'),
#               AIMessage(content='Obrigado! Fiz uma busca por imóveis em Aquarela das Artes que se aproximam das suas preferências (3 dormitórios, 2 banheiros, 2 vagas, ~200 m²). Note que é difícil encontrar exatamente 200 m² com 2 banheiros nessa região, então listei opções próximas e com dados disponíveis.\n\nOpções encontradas em Aquarela das Artes (aproximações)\n- Viva Real — Avenida das Artes, Aquarela das Artes, Sinop\n  - Área: 215 m²\n  - Banheiros: 3\n  - Vagas: 2\n  - Observação: atende 2 vagas, mas possui 3 banheiros (acima do desejado). Link: [resumo da página]\n\n- Zap Imóveis — Aquarela das Artes, Sinop\n  - Área: 188 m²\n  - Quartos: 3\n  - Banheiros: 3\n  - Vagas: 2\n  - Observação: próximo de 200 m² e 3 dorms, mas tem 3 banheiros (acima do desejado). Link: [resumo da página]\n\n- Baza Imobiliária — Aquarela das Artes, Sinop\n  - Quartos: 3\n  - Banheiros: 2\n  - Vagas: não especificado (geralmente 2)\n  - Observação: informa 3 quartos e 2 banheiros; área não informada no snippet. Link: [resumo da página]\n\n- Kenlo (Aquarela das Artes) — Sinop\n  - Quartos: 3 suítes\n  - Banheiro(s): 1\n  - Vagas: 2\n  - Área: ~171,9 m²\n  - Observação: atende 3 dorms (na prática são suítes), mas com apenas 1 banheiro e área menor que 200 m². Link: [resumo da página]\n\n- Instagram (opção de venda/localização)\n  - Detalhes variam; geralmente fotos e preço, sem ficha técnica completa.\n  - Observação: menos confiável para comparação de parâmetros exatos.\n\nResumo rápido\n- Não encontrei até o momento um imóvel que cumpra exatamente 3 dorms, 2 banheiros, 2 vagas e 200 m² em Aquarela das Artes com as informações disponíveis nas fontes pesquisadas.\n- As opções mais próximas costumam ter 188–215 m², com 3 dorms, mas com 3 banheiros ou com 1 banheiro, o que foge do seu requisito de 2 banheiros.\n\nComo posso ajudar agora\n- Quer que eu refine a busca para:\n  - manter 3 dorms e 2 vagas, ampliar a faixa de área para 180–230 m², e procurar apenas imóveis com exatamente 2 banheiros?\n  - ou expandir para bairros vizinhos próximos a Aquarela das Artes?\n- Deseja que eu filtre por faixa de preço (ex.: até R$ 900.000,00 ou entre R$ 700.000 e R$ 1.000.000)?\n- Posso agendar visitas, solicitar mais fotos/plantas dos imóveis que chegaram mais perto do seu perfil, ou calcular parcelas para as opções que se encaixem melhor?\n\nDiga como prefere seguir e eu sigo já com as próximas ações.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 3081, 'prompt_tokens': 1323, 'total_tokens': 4404, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 2368, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-DA2hGotkIWchdvQpujSFgYX2jAbRk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019c68df-b664-7351-8a77-92b02c0449d3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1323, 'output_tokens': 3081, 'total_tokens': 4404, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 2368}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Obrigado! Fiz uma busca por imóveis em Aquarela das Artes que se aproximam das suas preferências (3 dormitórios, 2 banheiros, 2 vagas, ~200 m²). Note que é difícil encontrar exatamente 200 m² com 2 banheiros nessa região, então listei opções próximas e com dados disponíveis.
#
# Opções encontradas em Aquarela das Artes (aproximações)
# - Viva Real — Avenida das Artes, Aquarela das Artes, Sinop
#   - Área: 215 m²
#   - Banheiros: 3
#   - Vagas: 2
#   - Observação: atende 2 vagas, mas possui 3 banheiros (acima do desejado). Link: [resumo da página]
#
# - Zap Imóveis — Aquarela das Artes, Sinop
#   - Área: 188 m²
#   - Quartos: 3
#   - Banheiros: 3
#   - Vagas: 2
#   - Observação: próximo de 200 m² e 3 dorms, mas tem 3 banheiros (acima do desejado). Link: [resumo da página]
#
# - Baza Imobiliária — Aquarela das Artes, Sinop
#   - Quartos: 3
#   - Banheiros: 2
#   - Vagas: não especificado (geralmente 2)
#   - Observação: informa 3 quartos e 2 banheiros; área não informada no snippet. Link: [resumo da página]
#
# - Kenlo (Aquarela das Artes) — Sinop
#   - Quartos: 3 suítes
#   - Banheiro(s): 1
#   - Vagas: 2
#   - Área: ~171,9 m²
#   - Observação: atende 3 dorms (na prática são suítes), mas com apenas 1 banheiro e área menor que 200 m². Link: [resumo da página]
#
# - Instagram (opção de venda/localização)
#   - Detalhes variam; geralmente fotos e preço, sem ficha técnica completa.
#   - Observação: menos confiável para comparação de parâmetros exatos.
#
# Resumo rápido
# - Não encontrei até o momento um imóvel que cumpra exatamente 3 dorms, 2 banheiros, 2 vagas e 200 m² em Aquarela das Artes com as informações disponíveis nas fontes pesquisadas.
# - As opções mais próximas costumam ter 188–215 m², com 3 dorms, mas com 3 banheiros ou com 1 banheiro, o que foge do seu requisito de 2 banheiros.
#
# Como posso ajudar agora
# - Quer que eu refine a busca para:
#   - manter 3 dorms e 2 vagas, ampliar a faixa de área para 180–230 m², e procurar apenas imóveis com exatamente 2 banheiros?
#   - ou expandir para bairros vizinhos próximos a Aquarela das Artes?
# - Deseja que eu filtre por faixa de preço (ex.: até R$ 900.000,00 ou entre R$ 700.000 e R$ 1.000.000)?
# - Posso agendar visitas, solicitar mais fotos/plantas dos imóveis que chegaram mais perto do seu perfil, ou calcular parcelas para as opções que se encaixem melhor?
#
# Diga como prefere seguir e eu sigo já com as próximas ações.
